# %% [markdown]
# <a href="https://colab.research.google.com/github/Yusep-T/data-science-2026/blob/main/Pertemuan5_Yusep_250401020103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# style visual
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (9,5)

# load dataset
tips = sns.load_dataset("titanic")

# tampilkan data
tips.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='class', data=df)

plt.title('Jumlah Penumpang Berdasarkan Kelas')
plt.xlabel('Class')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# Markdown Narasi
# What?
#
# Grafik menunjukkan bahwa kelas ekonomi (Third) memiliki jumlah penumpang paling banyak dibandingkan kelas lainnya. Jumlah penumpang kelas ketiga mencapai lebih dari 450 orang, sedangkan kelas pertama sekitar 200 orang. Hal ini memperlihatkan distribusi penumpang yang tidak merata antar kelas.
#
# So what?
#
# Distribusi ini penting karena kelas penumpang kemungkinan memengaruhi tingkat keselamatan dan fasilitas selama perjalanan. Dengan jumlah penumpang kelas tiga yang jauh lebih besar, risiko kepadatan dan keterbatasan akses penyelamatan bisa lebih tinggi. Analisis ini membantu memahami struktur sosial penumpang Titanic.
#
# Now what?
#
# Analisis berikutnya dapat membandingkan tingkat keselamatan (survived) berdasarkan kelas penumpang. Kita juga dapat mengeksplorasi hubungan antara kelas dengan usia atau tarif tiket (fare). Hal ini dapat memberikan insight tentang faktor yang memengaruhi peluang bertahan hidup.

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['age'].dropna(), bins=20, kde=True)

plt.title('Distribusi Umur Penumpang')
plt.xlabel('Umur')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Markdown Narasi
# What?
#
# Histogram menunjukkan bahwa sebagian besar penumpang berusia antara 20 hingga 40 tahun. Puncak distribusi berada di sekitar usia 25–30 tahun. Selain itu, terdapat lebih sedikit penumpang dengan usia di atas 60 tahun.
#
# So what?
#
# Distribusi usia penting untuk memahami karakteristik demografis penumpang Titanic. Dominasi usia dewasa muda menunjukkan bahwa mayoritas penumpang berada pada usia produktif. Informasi ini dapat memengaruhi analisis tingkat keselamatan berdasarkan kelompok usia.
#
# Now what?
#
# Langkah selanjutnya adalah membandingkan peluang keselamatan berdasarkan kategori usia, misalnya anak-anak, dewasa, dan lansia. Kita juga dapat membuat analisis tambahan menggunakan boxplot untuk melihat penyebaran umur pada tiap kelas penumpang. Hal ini membantu menemukan pola risiko berdasarkan usia.

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='class', y='fare', data=df)

plt.title('Distribusi Fare Berdasarkan Kelas')
plt.xlabel('Class')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# Markdown Narasi
# What?
#
# Boxplot menunjukkan bahwa penumpang kelas pertama memiliki tarif tiket (fare) paling tinggi dibandingkan kelas lainnya. Median tarif kelas pertama berada jauh di atas kelas kedua dan ketiga. Selain itu, terdapat beberapa outlier dengan harga tiket yang sangat mahal.
#
# So what?
#
# Perbedaan tarif ini menggambarkan kesenjangan ekonomi antar penumpang Titanic. Harga tiket yang tinggi kemungkinan berkaitan dengan fasilitas yang lebih baik dan lokasi kabin yang lebih aman. Faktor ekonomi ini dapat berpengaruh terhadap peluang keselamatan penumpang.
#
# Now what?
#
# Analisis lanjutan dapat dilakukan untuk melihat hubungan antara tarif tiket dengan status keselamatan (survived). Kita juga dapat mengeksplorasi apakah outlier tiket mahal memiliki tingkat keselamatan yang lebih tinggi. Hal ini membantu memahami pengaruh faktor ekonomi terhadap hasil perjalanan.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='age', y='fare', hue='survived', data=df)

plt.title('Hubungan Umur dan Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# Markdown Narasi
# What?
#
# Scatter plot menunjukkan hubungan antara umur penumpang dan harga tiket (fare). Sebagian besar tiket mahal dimiliki oleh penumpang dengan usia dewasa. Selain itu, terlihat bahwa penumpang yang selamat (survived = 1) lebih banyak berada pada kelompok tarif tinggi.
#
# So what?
#
# Pola ini menunjukkan kemungkinan hubungan antara status ekonomi dan peluang keselamatan. Penumpang dengan tiket mahal cenderung berasal dari kelas atas yang memiliki akses lebih baik terhadap fasilitas keselamatan. Informasi ini penting untuk memahami faktor sosial dalam tragedi Titanic.
#
# Now what?
#
# Langkah berikutnya adalah menghitung korelasi antara fare, class, dan survived. Kita juga dapat membuat model prediksi sederhana untuk melihat faktor mana yang paling berpengaruh terhadap keselamatan. Analisis ini dapat memberikan insight yang lebih mendalam tentang data Titanic.
